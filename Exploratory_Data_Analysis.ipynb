# %% [markdown]
# ## Exploratory Data Analysis
# ### EDA stands for Exploratory Data Analysis. It's a crucial first step whenever you're working with a dataset, especially
# ### in data science.
# ### It involves using statistical methods and visualizations to get a feel for the data, identify patterns and trends,
# ### and uncover any potential issues.
# ### Let's do eda on dataset again!😅

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Set option to display max columns i.e (Display all the columns of the dataframe).
pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('House Pricing Dataset/train.csv')
# print shape of dataset with rows and columns
print(dataset.shape)
# Out:
# (1460, 81)

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# Let's describe the dataset
dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# Let's get info of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ### Conclusion:
# #### There are many missing values in certain features of dataset as you can see in info of dataset. Let's simplify this in coming cell.

# %%
## Let's create list of features which has missing values.
missing_values_features = [i for i in dataset.columns if dataset[i].isnull().sum()>1]
missing_values_features
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
## ohkey, this features has missing values. Now, let's check how many values are missing regarding to feature.
for i in missing_values_features:
    print(i, np.round(dataset[i].isnull().mean(), 3), '% are missing values')
# Out:
# LotFrontage 0.177 % are missing values
# Alley 0.938 % are missing values
# MasVnrType 0.597 % are missing values
# MasVnrArea 0.005 % are missing values
# BsmtQual 0.025 % are missing values
# BsmtCond 0.025 % are missing values
# BsmtExposure 0.026 % are missing values
# BsmtFinType1 0.025 % are missing values
# BsmtFinType2 0.026 % are missing values
# FireplaceQu 0.473 % are missing values
# GarageType 0.055 % are missing values
# GarageYrBlt 0.055 % are missing values
# GarageFinish 0.055 % are missing values
# GarageQual 0.055 % are missing values
# GarageCond 0.055 % are missing values
# PoolQC 0.995 % are missing values
# Fence 0.808 % are missing values
# MiscFeature 0.963 % are missing values

# %% [markdown]
# ### Conclusion
# #### We conclude that the features like [alley, poolqc, miscfeature, fence] has more missing values i.e: approx to 99%.
# #### There are many missing values. So, before we do fill that with some values, let's check their relation with saleprice.

# %%
for i in missing_values_features:
    data = dataset.copy()
    
    # 1 indicates for missing values and 0 indicates for non missing values.
    data[i] = np.where(dataset[i].isnull(), 1, 0)
    
    # let's plot it.
    data.groupby(i)['SalePrice'].mean().plot.bar()
    plt.title(i)
    plt.show()

# %% [markdown]
# ### Conclusion:
# #### We conclude that some features's missing values are important to saleprice. They can play a significant role regarding to saleprice.

# %% [markdown]
# ### Let's check numerical variables and categorical variables.

# %%
numerical_features = [i for i in dataset.columns if dataset[i].dtypes != 'O']
categorical_features = [j for j in dataset.columns if dataset[j].dtypes == 'O']
print('The numerical features are:' , len(numerical_features), '\nThe categorical features are:', len(categorical_features))
dataset[numerical_features].head()
# Out:
# The numerical features are: 38
# The categorical features are: 43
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# ...

# %% [markdown]
# ### There are two types of numerical variables.
# #### 1. Discrete variable
# #### 2. Continous variable

# %%
# Let's check Discrete variable first
discrete_variables = [i for i in numerical_features if len(dataset[i].unique())<20 and i not in ['Id']]
dataset[discrete_variables].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0          60            7            5             1             0         2
# 1          20            6            8             0             1         2
# 2          60            7            5             1             0         2
# 3          70            7            5             1             0         1
# 4          60            8            5             1             0         2
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  \
# 0         1             3             1             8           0           2
# 1         0             3             1             6           1           2
# 2         1             3             1             6           1           2
# 3         0             3             1             7           1           3
# 4         1             4             1             9           1           3
#
#    PoolArea  MoSold  YrSold
# ...

# %%
## Now, find relationship between discrete variables with sale price
for i in discrete_variables:
    data = dataset.copy()
    data.groupby(i)['SalePrice'].mean().plot.bar()
    plt.xlabel(i)
    plt.ylabel('SalePrice')
    plt.title(i)
    plt.show()

# %% [markdown]
# ### Conclusion
# #### We can see relationship of different features with SalePrice.

# %%
# Now, let's play with continue variables.
continous_feature = [i for i in numerical_features if i not in discrete_variables + ['Id']]
dataset[continous_feature].head()
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         65.0     8450       2003          2003       196.0         706
# 1         80.0     9600       1976          1976         0.0         978
# 2         68.0    11250       2001          2002       162.0         486
# 3         60.0     9550       1915          1970         0.0         216
# 4         84.0    14260       2000          2000       350.0         655
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0           0        150          856       856       854             0
# 1           0        284         1262      1262         0             0
# 2           0        434          920       920       866             0
# 3           0        540          756       961       756             0
# 4           0        490         1145      1145      1053             0
#
#    GrLivArea  GarageYrBlt  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# ...

# %%
for i in continous_feature:
    data = dataset.copy()
    data[i].hist(bins=20)
    plt.ylabel(i)
    plt.xlabel("count")
    plt.title(i)
    plt.show()

# %% [markdown]
# ### As we see, the graph is not forming bell curve, it's means the data is skewed. We can make it to bell curve by
# ### taking logarithmic method.

# %%
for i in continous_feature:
    data=dataset.copy()
    if 0 in data[i].unique():
        pass
    else:
        data[i]=np.log(data[i])
        data[i].hist(bins=20)
        plt.xlabel(i)
        plt.ylabel('SalesPrice')
        plt.title(i)
        plt.show()

# %% [markdown]
# ### We notice that data has many outliers. We can check outliers by box plotting.

# %%
for i in continous_feature:
    data=dataset.copy()
    if 0 in data[i].unique():
        pass
    else:
        data[i]=np.log(data[i])
        data.boxplot(column=i)
        plt.xlabel(i)
        plt.title(i)
        plt.show()

# %% [markdown]
# ### Now, let's find relationship between categorical and saleprice feature.

# %%
for i in categorical_features:
    data = dataset.copy()
    data.groupby(i)['SalePrice'].mean().plot.bar()
    plt.xlabel(i)
    plt.ylabel('SalePrice')
    plt.title(i)
    plt.show()

# %% [markdown]
# #### As we can see from bar graph for categorical features. We can conclude from this, which category is major in number i.e: from MSZoning,
# #### the category 'FV' is major in number. As the number of FV increasing, the saleprice is also increasing.

# %% [markdown]
# ## Findings:
# ### 1. As we see from dataset.describe, it's telling us that more features has high std so it's means data is spread out.
# ### 2. Data has more missing values and they are playing a significant role regarding to saleprice.
# ### 3. We see that the number of features of numerical are 38 while the number of features of categorical are 43.
# ### 4. We notice that data has many outliers.
