# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Let's try a little big data
X_train = np.array([1.0 , 1.7 , 2.0 , 2.5 , 3.0 , 3.2])
Y_train = ([250 , 300 , 480 , 430 , 630 , 730])

# %%
# Now, Find cost function for find that how much well is our linear regression model is predicting prices for houses.
def compute_cost(x,y,w,b):
    m = len(X_train)
    cost_sum = 0
    for i in range(len(X_train)):
        f_wb = w*x[i]+b
        cost = (f_wb - y[i]) ** 2
        cost_sum += cost
        total_cost = (1/(2*m)) * cost_sum
    return total_cost

# %%
# Your goal is to minimize the cost function as much as possible
MinimumCost = compute_cost(x_train , y_train , 200 , 23)
print(f"Your Minimum Cost is = {MinimumCost}")
# Out:
# Your Minimum Cost is = 1761.1666666666665
